# %% [markdown]
# <a href="https://colab.research.google.com/github/andrew3690/F-A_root_project/blob/Brazil/Data_Formating.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install pyarrow
! pip install fastparquet
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import pandas as pd
import os

# %% [markdown]
# Gooogle Colab Version

# %%
""" 
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
 """
# Out:
# " \nfrom google.colab import drive\ndrive.mount('/content/gdrive', force_remount=True)\n "

# %% [markdown]
# Local Machine Version

# %%
stocks = pd.read_excel(r"../RAW_DATA/tst/AtivosBR.xlsx",
                       sheet_name="historical_data")

# %% [markdown]
# The next cells format the stocks excel file

# %%
stocks
# Out:
#       Unnamed: 0   asOfDate periodType  EnterpriseValue  \
# 0              0 2021-02-12        TTM              NaN
# 1              1 2022-06-30         3M     2.477858e+09
# 2              2 2022-09-30         3M     3.051989e+09
# 3              3 2023-03-07        TTM     2.792264e+09
# 4              4 2023-03-08        TTM              NaN
# ...          ...        ...        ...              ...
# 2735        2735 2022-12-31         3M     2.345525e+10
# 2736        2736 2023-03-31         3M     2.261832e+10
# 2737        2737 2023-07-14        TTM              NaN
# 2738        2738 2023-07-17        TTM     2.542939e+10
# 2739        2739 2023-07-18        TTM              NaN
#
#       EnterprisesValueEBITDARatio  EnterprisesValueRevenueRatio  \
# 0                             NaN                           NaN
# 1                       66.960080                      8.677917
# 2                       31.825035                      9.672702
# ...

# %%
for column in stocks.columns:
    print(column)
# Out:
# Unnamed: 0
# asOfDate
# periodType
# EnterpriseValue
# EnterprisesValueEBITDARatio
# EnterprisesValueRevenueRatio
# ForwardPeRatio
# MarketCap
# PbRatio
# PeRatio
# PegRatio
# PsRatio
# Symbol

# %%
# Renaming column Unnamed to Ticker and set it as index 
stocks.rename(columns = {'Symbol':'Ticker'},inplace = True)
stocks.set_index('Ticker')

stocks.columns
# Out:
# Index(['Unnamed: 0', 'asOfDate', 'periodType', 'EnterpriseValue',
#        'EnterprisesValueEBITDARatio', 'EnterprisesValueRevenueRatio',
#        'ForwardPeRatio', 'MarketCap', 'PbRatio', 'PeRatio', 'PegRatio',
#        'PsRatio', 'Ticker'],
#       dtype='object')

# %%
stocks
# Out:
#       Unnamed: 0   asOfDate periodType  EnterpriseValue  \
# 0              0 2021-02-12        TTM              NaN
# 1              1 2022-06-30         3M     2.477858e+09
# 2              2 2022-09-30         3M     3.051989e+09
# 3              3 2023-03-07        TTM     2.792264e+09
# 4              4 2023-03-08        TTM              NaN
# ...          ...        ...        ...              ...
# 2735        2735 2022-12-31         3M     2.345525e+10
# 2736        2736 2023-03-31         3M     2.261832e+10
# 2737        2737 2023-07-14        TTM              NaN
# 2738        2738 2023-07-17        TTM     2.542939e+10
# 2739        2739 2023-07-18        TTM              NaN
#
#       EnterprisesValueEBITDARatio  EnterprisesValueRevenueRatio  \
# 0                             NaN                           NaN
# 1                       66.960080                      8.677917
# 2                       31.825035                      9.672702
# ...

# %%
# stocks_columns = ['regularMarketVolume', 'regularMarketPreviousClose','regularMarketOpen',
#                   'regularMarketPrice', 'regularMarketDayHigh','regularMarketDayLow',
#                   'regularMarketChangePercent','shortName', 'longName',
#                   'marketCap','lastMarket']

# %%
# #Selecting columns that should be dropped
selected_columns = ['regularMarketSource','maxAge','Unnamed: 0', 
                    'exchange', 'fromCurrency', 'quoteType', 
                    'priceHint', 'fromCurrency', 'toCurrency', 
                    'lastMarket','underlyingSymbol','currency',
                    'quoteSourceName', 'currencySymbol', 'fromCurrency', 'toCurrency']

stocks.drop(columns=selected_columns,inplace=True)

# %%
stocks
# Out:
#                       regularMarketChangePercent  \
# 0                                       0.022082
# 1                                       0.104478
# 2                                       0.107527
# 3                                       0.005634
# 4                                      -0.002128
# ..                                           ...
# 374  Quote not found for ticker symbol: CESP6.SA
# 375  Quote not found for ticker symbol: CESP5.SA
# 376  Quote not found for ticker symbol: CESP3.SA
# 377                                     0.017614
# 378                                      0.02067
#
#                              regularMarketChange  \
# 0                                           0.07
# 1                                           0.49
# 2                                            0.5
# 3                                           0.02
# 4                                      -1.039978
# ..                                           ...
# ...

# %%
string_to_drop = "Quote not found for ticker symbol: "
stocks = stocks[~stocks['Ticker'].str.contains(string_to_drop)]

# %%
stocks['Ticker'] = stocks['Ticker'].str.replace('.SA', '')
# Out:
# /tmp/ipykernel_4446/4222243210.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stocks['Ticker'] = stocks['Ticker'].str.replace('.SA', '')

# %%
stocks
# Out:
#     regularMarketChangePercent regularMarketChange    regularMarketTime  \
# 0                     0.022082                0.07  2023-07-13 17:07:57
# 1                     0.104478                0.49  2023-07-13 16:53:24
# 2                     0.107527                 0.5  2023-07-13 17:07:34
# 3                     0.005634                0.02  2023-07-13 17:06:00
# 4                    -0.002128           -1.039978  2023-07-13 16:12:24
# ..                         ...                 ...                  ...
# 371                   0.008358            0.459999  2023-07-13 17:07:35
# 372                   0.000386                0.01  2023-07-13 14:53:15
# 373                          0                   0  2023-07-07 11:32:50
# 377                   0.017614                0.22  2023-07-13 17:07:38
# 378                    0.02067            0.370001  2023-07-13 17:07:54
#
#     regularMarketPrice regularMarketDayHigh regularMarketDayLow  \
# ...

# %%
stocks.columns
# Out:
# Index(['regularMarketChangePercent', 'regularMarketChange',
#        'regularMarketTime', 'regularMarketPrice', 'regularMarketDayHigh',
#        'regularMarketDayLow', 'regularMarketVolume',
#        'regularMarketPreviousClose', 'regularMarketOpen', 'exchangeName',
#        'exchangeDataDelayedBy', 'marketState', 'Ticker', 'shortName',
#        'longName', 'marketCap'],
#       dtype='object')

# %%
stocks.rename(
            columns= {
                'regularMarketChangePercent': 'Porcentagem_de_Mudança_do_Mercado_Regular',
                'regularMarketChange': 'Mudanca_do_Mercado_Regular',
                'regularMarketTime': 'Horario_do_Mercado_Regular',
                'regularMarketPrice': 'Preco_do_Mercado_Regular',
                'regularMarketDayHigh': 'Maxima_do_Mercado_Regular',
                'regularMarketDayLow': 'Minima_do_Mercado_Regular',
                'regularMarketVolume': 'Volume_do_Mercado_Regular',
                'regularMarketPreviousClose': 'Fechamento_Anterior_do_Mercado_Regular',
                'regularMarketOpen': 'Abertura_do_Mercado_Regular',
                'exchangeName': 'Nome_da_Bolsa',
                'exchangeDataDelayedBy': 'Dados_da_Bolsa_Atrasados_em',
                'marketState': 'Estado_do_Mercado',
                'Ticker': 'Ticker',
                'shortName': 'Nome_Curto',
                'longName': 'Nome_Longo',
                'marketCap': 'Capitalizacao_de_Mercado'
                }, inplace = True)
# Out:
# /tmp/ipykernel_4446/3966684205.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stocks.rename(

# %%
stocks
# Out:
#     Porcentagem_de_Mudança_do_Mercado_Regular Mudanca_do_Mercado_Regular  \
# 0                                    0.022082                       0.07
# 1                                    0.104478                       0.49
# 2                                    0.107527                        0.5
# 3                                    0.005634                       0.02
# 4                                   -0.002128                  -1.039978
# ..                                        ...                        ...
# 371                                  0.008358                   0.459999
# 372                                  0.000386                       0.01
# 373                                         0                          0
# 377                                  0.017614                       0.22
# 378                                   0.02067                   0.370001
#
#     Horario_do_Mercado_Regular Preço_do_Mercado_Regular  \
# ...

# %%
# stocks.to_parquet(path=r'../RAW_DATA/Parquet/tst/AtivosBr.parquet')

# Define the output directory and filename
output_directory = "../Final/Parquet/tst/"

# Create the output directory if it doesn't exist
os.makedirs(output_directory, exist_ok=True)

output_directory = output_directory + "" + "/AtivosBr.parquet"

stocks.to_parquet(output_directory)
