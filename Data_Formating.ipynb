# %% [markdown]
# <a href="https://colab.research.google.com/github/andrew3690/F-A_root_project/blob/Brazil/Data_Formating.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd

# %%
stocks = pd.read_excel('/content/gdrive/MyDrive/Data/XLXS/RAW/AtivosBr.xlsx',
                       sheet_name='stocks')

key_stats = pd.read_excel('/content/gdrive/MyDrive/Data/XLXS/RAW/Beta.xlsx',
                       sheet_name='key_stats')

beta = pd.read_excel('/content/gdrive/MyDrive/Data/XLXS/RAW/Financial.xlsx',
                      sheet_name='financial_data')

price = pd.read_excel('/content/gdrive/MyDrive/Data/XLXS/RAW/Price.xlsx',
                      sheet_name='price')

# %% [markdown]
# The next cells format the stocks excel file

# %%
stocks.rename(columns = {'Unnamed: 0':'Ticker'},inplace = True)
stocks.set_index('Ticker')
cols = ['maxAge','recommendationKey','targetHighPrice','targetLowPrice','targetMeanPrice','targetMedianPrice','recommendationMean','numberOfAnalystOpinions']
stocks.drop(cols,axis=1,inplace=True)
stocks
# Out:
#         Ticker                                 currentPrice  \
# 0    N2ET34.SA                                        13.21
# 1    M1TA34.SA                                        21.57
# 2     AERI3.SA                                         0.98
# 3     ICBR3.SA  Quote not found for ticker symbol: ICBR3.SA
# 4     DOTZ3.SA                                         1.24
# ..         ...                                          ...
# 373   CESP6.SA  Quote not found for ticker symbol: CESP6.SA
# 374   CESP5.SA  Quote not found for ticker symbol: CESP5.SA
# 375   CESP3.SA  Quote not found for ticker symbol: CESP3.SA
# 376   CMIG4.SA                                        10.72
# 377   CMIG3.SA                                         16.4
#
#                                        totalCash  \
# 0                                     1636262016
# 1                                    41776001024
# 2                                      856392000
# 3    Quote not found for ticker symbol: ICBR3.SA
# 4                                      199554000
# ..                                           ...
# 373  Quote not found for ticker symbol: CESP6.SA
# 374  Quote not found for ticker symbol: CESP5.SA
# 375  Quote not found for ticker symbol: CESP3.SA
# 376                                   4769682944
# 377                                   4769682944
#
#                                totalCashPerShare  \
# 0                                          4.979
# 1                                          0.551
# 2                                          1.123
# 3    Quote not found for ticker symbol: ICBR3.SA
# 4                                          1.531
# ..                                           ...
# 373  Quote not found for ticker symbol: CESP6.SA
# 374  Quote not found for ticker symbol: CESP5.SA
# 375  Quote not found for ticker symbol: CESP3.SA
# 376                                        2.168
# 377                                        2.168
#
#                                           ebitda  \
# 0                                     -130562000
# 1                                    43867000832
# 2                                      261630000
# 3    Quote not found for ticker symbol: ICBR3.SA
# 4                                     -103156000
# ..                                           ...
# 373  Quote not found for ticker symbol: CESP6.SA
# 374  Quote not found for ticker symbol: CESP5.SA
# 375  Quote not found for ticker symbol: CESP3.SA
# 376                                   6018060800
# 377                                   6018060800
#
#                                        totalDebt  \
# 0                                     1567572992
# 1                                    26481000448
# 2                                     1573576960
# 3    Quote not found for ticker symbol: ICBR3.SA
# 4                                      109667000
# ..                                           ...
# 373  Quote not found for ticker symbol: CESP6.SA
# 374  Quote not found for ticker symbol: CESP5.SA
# 375  Quote not found for ticker symbol: CESP3.SA
# 376                                  11613667328
# 377                                  11613667328
#
#                                       quickRatio  \
# 0                                          5.218
# 1                                          2.336
# 2                                           1.12
# 3    Quote not found for ticker symbol: ICBR3.SA
# 4                                          0.698
# ..                                           ...
# 373  Quote not found for ticker symbol: CESP6.SA
# 374  Quote not found for ticker symbol: CESP5.SA
# 375  Quote not found for ticker symbol: CESP3.SA
# 376                                        1.087
# 377                                        1.087
#
#                                     currentRatio  \
# 0                                          5.352
# 1                                           2.57
# 2                                          2.194
# 3    Quote not found for ticker symbol: ICBR3.SA
# 4                                          0.817
# ..                                           ...
# 373  Quote not found for ticker symbol: CESP6.SA
# 374  Quote not found for ticker symbol: CESP5.SA
# 375  Quote not found for ticker symbol: CESP3.SA
# 376                                        1.271
# 377                                        1.271
#
#                                     totalRevenue  \
# 0                                      894137024
# 1                                   118115000320
# 2                                     2403173888
# 3    Quote not found for ticker symbol: ICBR3.SA
# 4                                      135492992
# ..                                           ...
# 373  Quote not found for ticker symbol: CESP6.SA
# 374  Quote not found for ticker symbol: CESP5.SA
# 375  Quote not found for ticker symbol: CESP3.SA
# 376                                  34366332928
# 377                                  34366332928
#
#                                     debtToEquity  ...  \
# 0                                        263.906  ...
# 1                                         21.339  ...
# 2                                        167.031  ...
# 3    Quote not found for ticker symbol: ICBR3.SA  ...
# 4                                            NaN  ...
# ..                                           ...  ...
# 373  Quote not found for ticker symbol: CESP6.SA  ...
# 374  Quote not found for ticker symbol: CESP5.SA  ...
# 375  Quote not found for ticker symbol: CESP3.SA  ...
# 376                                       55.095  ...
# 377                                       55.095  ...
#
#                                     grossProfits  \
# 0                                      509292000
# 1                                    95280000000
# 2                                      286975000
# 3    Quote not found for ticker symbol: ICBR3.SA
# 4                                      110322000
# ..                                           ...
# 373  Quote not found for ticker symbol: CESP6.SA
# 374  Quote not found for ticker symbol: CESP5.SA
# 375  Quote not found for ticker symbol: CESP3.SA
# 376                                   6305237000
# 377                                   6305237000
#
#                                     freeCashflow  \
# 0                                       83272872
# 1                                    19749376000
# 2                                     -166171008
# 3    Quote not found for ticker symbol: ICBR3.SA
# 4                                     -181799504
# ..                                           ...
# 373  Quote not found for ticker symbol: CESP6.SA
# 374  Quote not found for ticker symbol: CESP5.SA
# 375  Quote not found for ticker symbol: CESP3.SA
# 376                                   2156866816
# 377                                   2156866816
#
#                                operatingCashflow  \
# 0                                       86089000
# 1                                    54067998720
# 2                                       41159000
# 3    Quote not found for ticker symbol: ICBR3.SA
# 4                                     -124830000
# ..                                           ...
# 373  Quote not found for ticker symbol: CESP6.SA
# 374  Quote not found for ticker symbol: CESP5.SA
# 375  Quote not found for ticker symbol: CESP3.SA
# 376                                   6194138112
# 377                                   6194138112
#
#                                    revenueGrowth  \
# 0                                          0.473
# 1                                         -0.045
# 2                                         -0.006
# 3    Quote not found for ticker symbol: ICBR3.SA
# 4                                           0.37
# ..                                           ...
# 373  Quote not found for ticker symbol: CESP6.SA
# 374  Quote not found for ticker symbol: CESP5.SA
# 375  Quote not found for ticker symbol: CESP3.SA
# 376                                       -0.032
# 377                                       -0.032
#
#                                     grossMargins  \
# 0                                        0.76814
# 1                                        0.80334
# 2                                        0.11629
# 3    Quote not found for ticker symbol: ICBR3.SA
# 4                                          0.898
# ..                                           ...
# 373  Quote not found for ticker symbol: CESP6.SA
# 374  Quote not found for ticker symbol: CESP5.SA
# 375  Quote not found for ticker symbol: CESP3.SA
# 376                                      0.18674
# 377                                      0.18674
#
#                                    ebitdaMargins  \
# 0                                       -0.14602
# 1                                        0.37139
# 2                                        0.10887
# 3    Quote not found for ticker symbol: ICBR3.SA
# 4                                       -0.76134
# ..                                           ...
# 373  Quote not found for ticker symbol: CESP6.SA
# 374  Quote not found for ticker symbol: CESP5.SA
# 375  Quote not found for ticker symbol: CESP3.SA
# 376                                      0.17512
# 377                                      0.17512
#
#                                 operatingMargins  \
# 0                                       -0.21383
# 1                                        0.30092
# 2                                         0.0863
# 3    Quote not found for ticker symbol: ICBR3.SA
# 4                                        -0.7338
# ..                                           ...
# 373  Quote not found for ticker symbol: CESP6.SA
# 374  Quote not found for ticker symbol: CESP5.SA
# 375  Quote not found for ticker symbol: CESP3.SA
# 376                                      0.14411
# 377                                      0.14411
#
#                                    profitMargins  \
# 0                                        -0.2516
# 1                                         0.2441
# 2                                       -0.01464
# 3    Quote not found for ticker symbol: ICBR3.SA
# 4                                       -0.65901
# ..                                           ...
# 373  Quote not found for ticker symbol: CESP6.SA
# 374  Quote not found for ticker symbol: CESP5.SA
# 375  Quote not found for ticker symbol: CESP3.SA
# 376                                      0.10617
# 377                                      0.10617
#
#                                financialCurrency  \
# 0                                            USD
# 1                                            USD
# 2                                            BRL
# 3    Quote not found for ticker symbol: ICBR3.SA
# 4                                            BRL
# ..                                           ...
# 373  Quote not found for ticker symbol: CESP6.SA
# 374  Quote not found for ticker symbol: CESP5.SA
# 375  Quote not found for ticker symbol: CESP3.SA
# 376                                          BRL
# 377                                          BRL
#
#                                   earningsGrowth
# 0                                            NaN
# 1                                         -0.491
# 2                                            NaN
# 3    Quote not found for ticker symbol: ICBR3.SA
# 4                                            NaN
# ..                                           ...
# 373  Quote not found for ticker symbol: CESP6.SA
# 374  Quote not found for ticker symbol: CESP5.SA
# 375  Quote not found for ticker symbol: CESP3.SA
# 376                                        1.807
# 377                                        1.807
#
# [378 rows x 23 columns]

# %%
tickers = list(stocks['Ticker'])
for i in tickers:
  stocks = stocks[~stocks['currentPrice'].isin(["Quote not found for ticker symbol: %s"%i,"No fundamentals data found for any of the summaryTypes=financialData"])]

# %%
stocks = stocks.astype({'Ticker': 'string',
                        'currentPrice': 'float',
                        'totalCash': 'float',
                        'ebitda': 'float',
                        'totalDebt': 'float'})
stocks.replace('NaN',0)
stocks.dtypes
# Out:
# Ticker                string
# currentPrice         float64
# totalCash            float64
# totalCashPerShare     object
# ebitda               float64
# totalDebt            float64
# quickRatio            object
# currentRatio          object
# totalRevenue          object
# debtToEquity          object
# revenuePerShare       object
# returnOnAssets        object
# returnOnEquity        object
# grossProfits          object
# freeCashflow          object
# operatingCashflow     object
# revenueGrowth         object
# grossMargins          object
# ebitdaMargins         object
# operatingMargins      object
# profitMargins         object
# financialCurrency     object
# earningsGrowth        object
# dtype: object

# %%
stocks.rename(columns= {'currentPrice':'Preco_Atual',
                        'totalCash':'Fluxo_de_caixa_total',
                        'totalCashPerShare':'Fluxo_de_caixa_por_acao',
                        'ebitda':'EBITDA',
                        'totalDebt':'Divida_total',
                        'quickRatio':'Liquidez_imediata',
                        'currentRatio':'Liquidez_corrente',
                        'totalRevenue':'Receita_total',
                        'debtToEquity':'Divida_Patrimonio',
                        'revenuePerShare':'Receita_por_acao',
                        'returnOnAssets':'ROA',
                        'returnOnEquity':'ROE',
                        'grossProfits':'Lucro_Bruto',
                        'freeCashflow':'Fluxo_de_Caixa_Livre',
                        'operatingCashflow':'Fluxo_de_caixa_operacional',
                        'revenueGrowth':'Crescimento_de_Receita_3T',
                        'grossMargins':'Margem_Bruta',
                        'ebitdaMargins':'Margem_EBITIDA',
                        'operatingMargins':'Margem_Operacional',
                        'profitMargins':'Margem_liquida',
                        'financialCurrency':'Moeda',
                        'earningsGrowth':'Crescimento_dos_ganhos_3T'}, inplace = True)

# %% [markdown]
# The next cells format the Key_stats Excel File

# %%
key_stats.rename(columns = {'Unnamed: 0':'Ticker'},inplace = True)
key_stats.set_index('Ticker')

cols = ['Ticker','beta','profitMargins','earningsQuarterlyGrowth','lastDividendDate','lastDividendValue']

stat = key_stats[cols]

# %%
stat.rename(columns={'beta':'Beta',
                     'profitMargins':'Margem_de_Lucro',
                     'earningsQuarterlyGrowth':'Crescimento_de_receitas_4T',
                     'lastDividendDate':'Data_do_ultimo_dividendo',
                     'lastDividendValue':'Valor_do_ultimo_dividendo'},inplace=True)
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
stat = stat.astype({'Ticker':'string',
                    'Beta': 'string',
                    'Margem_de_Lucro':'string',
                    'Valor_do_ultimo_dividendo':'string'})

stat.replace('<NA>',0)
# Out:
#         Ticker                                         Beta  \
# 0    N2ET34.SA                                     1.005082
# 1    M1TA34.SA                                     1.204382
# 2     AERI3.SA                                     0.827878
# 3     ICBR3.SA  Quote not found for ticker symbol: ICBR3.SA
# 4     DOTZ3.SA                                         <NA>
# ..         ...                                          ...
# 373   CESP6.SA  Quote not found for ticker symbol: CESP6.SA
# 374   CESP5.SA  Quote not found for ticker symbol: CESP5.SA
# 375   CESP3.SA  Quote not found for ticker symbol: CESP3.SA
# 376   CMIG4.SA                                     0.543463
# 377   CMIG3.SA                                     0.543463
#
#                                  Margem_de_Lucro  \
# 0                                        -0.2516
# 1                                         0.2441
# 2                                       -0.01464
# 3    Quote not found for ticker symbol: ICBR3.SA
# 4                                       -0.65901
# ..                                           ...
# 373  Quote not found for ticker symbol: CESP6.SA
# 374  Quote not found for ticker symbol: CESP5.SA
# 375  Quote not found for ticker symbol: CESP3.SA
# 376                                      0.10617
# 377                                      0.10617
#
#                       Crescimento_de_receitas_4T  \
# 0                                           <NA>
# 1                                         -0.522
# 2                                           <NA>
# 3    Quote not found for ticker symbol: ICBR3.SA
# 4                                           <NA>
# ..                                           ...
# 373  Quote not found for ticker symbol: CESP6.SA
# 374  Quote not found for ticker symbol: CESP5.SA
# 375  Quote not found for ticker symbol: CESP3.SA
# 376                                        1.807
# 377                                        1.807
#
#                         Data_do_ultimo_dividendo  \
# 0                                           <NA>
# 1                                           <NA>
# 2                                     1648425600
# 3    Quote not found for ticker symbol: ICBR3.SA
# 4                                           <NA>
# ..                                           ...
# 373  Quote not found for ticker symbol: CESP6.SA
# 374  Quote not found for ticker symbol: CESP5.SA
# 375  Quote not found for ticker symbol: CESP3.SA
# 376                                   1671667200
# 377                                   1671667200
#
#                        Valor_do_ultimo_dividendo
# 0                                           <NA>
# 1                                           <NA>
# 2                                       0.020702
# 3    Quote not found for ticker symbol: ICBR3.SA
# 4                                           <NA>
# ..                                           ...
# 373  Quote not found for ticker symbol: CESP6.SA
# 374  Quote not found for ticker symbol: CESP5.SA
# 375  Quote not found for ticker symbol: CESP3.SA
# 376                                     0.181142
# 377                                     0.181142
#
# [378 rows x 6 columns]

# %% [markdown]
# The next cells format the Beta Excel File

# %%
tickers = list(stocks['Ticker'])
for i in tickers:
  stat = stat[~stat['Beta'].isin(["Quote not found for ticker symbol: %s"%i,"No fundamentals data found for any of the summaryTypes=financialData"])]

# %%
beta.rename(columns= {'NetDebt':'Divida_Liquida','symbol':'Ticker'},inplace=True)
beta.set_index('Ticker')

##
cols = ['asOfDate','periodType','currencyCode'] 
beta.drop(cols,axis=1,inplace=True)

# %%
price.rename(columns = {'Unnamed: 0':'Ticker'},inplace = True)
price.set_index('Ticker')

cols = ['Ticker','marketCap','regularMarketVolume']
price = price[cols]

price
# Out:
#         Ticker                                    marketCap  \
# 0    N2ET34.SA                                          NaN
# 1    M1TA34.SA                                1608960180224
# 2     AERI3.SA                                    747300992
# 3     ICBR3.SA  Quote not found for ticker symbol: ICBR3.SA
# 4     DOTZ3.SA                                    161289280
# ..         ...                                          ...
# 373   CESP6.SA  Quote not found for ticker symbol: CESP6.SA
# 374   CESP5.SA  Quote not found for ticker symbol: CESP5.SA
# 375   CESP3.SA  Quote not found for ticker symbol: CESP3.SA
# 376   CMIG4.SA                                  28200138752
# 377   CMIG3.SA                                  27227934720
#
#                              regularMarketVolume
# 0                                              0
# 1                                              0
# 2                                              0
# 3    Quote not found for ticker symbol: ICBR3.SA
# 4                                              0
# ..                                           ...
# 373  Quote not found for ticker symbol: CESP6.SA
# 374  Quote not found for ticker symbol: CESP5.SA
# 375  Quote not found for ticker symbol: CESP3.SA
# 376                                            0
# 377                                            0
#
# [378 rows x 3 columns]

# %%
price = price.astype({'Ticker':'string',
                      'marketCap': 'string',
                      'regularMarketVolume':'string'})

# %%
price.rename(columns={'marketCap':'valor_de_mercado',
                      'regularMarketVolume':'volume_de_mercado'},inplace=True)

# %%
stocks.to_parquet(path='/content/gdrive/MyDrive/Data/Parquet/Formated/BrStocksFormated.parquet')

beta.to_parquet(path='/content/gdrive/MyDrive/Data/Parquet/Formated/Ebit.parquet')

stat.to_parquet(path='/content/gdrive/MyDrive/Data/Parquet/Formated/Stat.parquet')

price.to_parquet(path='/content/gdrive/MyDrive/Data/Parquet/Formated/Price.parquet')
